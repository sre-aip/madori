# %% [markdown]
# # 5.1-2 DCGANの作成
#
# - 本ファイルでは、DCGANのネットワークを実装とDCGANの学習をします。

# %% [markdown]
# # 5.1 学習目標
#
# 1.	Generatorが画像を生成するためにどのようなニューラルネットワークの構造になっているのかを理解する
# 2.	Discriminatorが画像の識別をするためにどのようなニューラルネットワークの構造になっているのかを理解する
# 3.	GANの一般的な損失関数の形とニューラルネットワークの学習の流れを理解する
# 4.	DCGANのネットワークを実装できるようになる

# %% [markdown]
# # 5.2 学習目標
#
# 1.	GANの損失関数の形を理解する
# 2.	DCGANを実装し、手書き数字画像が生成できる

# %% [markdown]
# # 事前準備
# 書籍の指示に従い、本章で使用するデータを用意します

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

import pathlib
from pathlib import Path

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # mnistデータ確認

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


f_img = Path("./data/img_78/img_7_0.jpg")
img = Image.open(f_img)
plt.imshow(img, 'gray')
plt.show()

print("データの次元: ", np.array(img).shape)
# Out:
# データの次元:  (64, 64)

# %%
nn.ConvTranspose2d()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 nn.ConvTranspose2d()
#
# TypeError: ConvTranspose2d.__init__() missing 3 required positional arguments: 'in_channels', 'out_channels', and 'kernel_size'

# %% [markdown]
# # 転置畳み込みの例

# %%
input = torch.tensor([[[[1.0, 1.0], [2.0, 2.0]]]])
print("入力データ")
print(input)
print("-----")

print("通常の畳み込み")
m = nn.Conv2d(1, 1, 2, stride=1, bias=False)
m.weight.data[0, 0, 0, 0] = 1
m.weight.data[0, 0, 0, 1] = 2
m.weight.data[0, 0, 1, 0] = 3
m.weight.data[0, 0, 1, 1] = 4
print("カーネル")
print(m.weight)
print("出力")
print(m(input))

print("-----")
print("転置畳み込み")
m = nn.ConvTranspose2d(1, 1, 2, stride=1, bias=False)
m.weight.data[0, 0, 0, 0] = 1
m.weight.data[0, 0, 0, 1] = 2
m.weight.data[0, 0, 1, 0] = 3
m.weight.data[0, 0, 1, 1] = 4
print("カーネル")
print(m.weight)
print("出力")
print(m(input))
# Out:
# 入力データ
# tensor([[[[1., 1.],
#           [2., 2.]]]])
# -----
# 通常の畳み込み
# カーネル
# Parameter containing:
# tensor([[[[1., 2.],
#           [3., 4.]]]], requires_grad=True)
# 出力
# tensor([[[[17.]]]], grad_fn=<ConvolutionBackward0>)
# -----
# 転置畳み込み
# カーネル
# Parameter containing:
# tensor([[[[1., 2.],
#           [3., 4.]]]], requires_grad=True)
# 出力
# tensor([[[[ 1.,  3.,  2.],
#           [ 5., 13.,  8.],
#           [ 6., 14.,  8.]]]], grad_fn=<ConvolutionBackward0>)

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        # z_dim:
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(z_dim, image_size * 8, kernel_size=4, stride=1),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True),
        )

        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 8, image_size * 4, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True),
        )

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 4, image_size * 2, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True),
        )

        self.layer4 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 2, image_size, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True),
        )

        self.last = nn.Sequential(nn.ConvTranspose2d(image_size, 1, kernel_size=4, stride=2, padding=1), nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 入力する乱数
input_z = torch.randn(1, 20)

# テンソルサイズを(1, 20, 1, 1)に変形
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
print("input_z shape: ", input_z.shape)

# 偽画像を出力
fake_images = G(input_z)
print("output shape: ", fake_images.shape)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()
# Out:
# input_z shape:  torch.Size([1, 20, 1, 1])
# output shape:  torch.Size([1, 1, 64, 64])

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, image_size, kernel_size=4, stride=2, padding=1), nn.LeakyReLU(0.1, inplace=True)
        )
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(image_size, image_size * 2, kernel_size=4, stride=2, padding=1), nn.LeakyReLU(0.1, inplace=True)
        )

        self.layer3 = nn.Sequential(
            nn.Conv2d(image_size * 2, image_size * 4, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True),
        )

        self.layer4 = nn.Sequential(
            nn.Conv2d(image_size * 4, image_size * 8, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True),
        )

        self.last = nn.Conv2d(image_size * 8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
D = Discriminator(z_dim=20, image_size=64)

# 偽画像を生成
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)

# 偽画像をDに入力
d_out = D(fake_images)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.5008]]]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# # 6.2へ

# %% [markdown]
# # GANの損失関数

# %%
# Dの誤差関数のイメージ実装
# maximize log(D(x)) + log(1 - D(G(z)))


# ※ xが未定義なので動作はエラーになります
# ---------------


# 正解ラベルを作成
mini_batch_size = 2
label_real = torch.full((mini_batch_size,), 1)

# 偽ラベルを作成
label_fake = torch.full((mini_batch_size,), 0)

# 誤差関数を定義
criterion = nn.BCEWithLogitsLoss(reduction="mean")

# 真の画像を判定
d_out_real = D(x)

# 偽の画像を生成して判定
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 誤差を計算
d_loss_real = criterion(d_out_real.view(-1), label_real)
d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
d_loss = d_loss_real + d_loss_fake
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 20
#      17 criterion = nn.BCEWithLogitsLoss(reduction="mean")
#      19 # 真の画像を判定
# ---> 20 d_out_real = D(x)
#      22 # 偽の画像を生成して判定
#      23 input_z = torch.randn(mini_batch_size, 20)
#
# NameError: name 'x' is not defined

# %%
# Gの誤差関数のイメージ実装
# maximize log(D(G(z)))


# ※ xが未定義なので動作はエラーになります
# ---------------


# 偽の画像を生成して判定
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 誤差を計算
g_loss = criterion(d_out_fake.view(-1), label_real)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。"""

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx) + ".jpg"
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx) + ".jpg"
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform:
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean, std)])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        """画像の枚数を返す"""
        return len(self.file_list)

    def __getitem__(self, index):
        """前処理をした画像のTensor形式のデータを取得"""

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list = make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# # 学習させる

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1:
        # Conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find("BatchNorm") != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 初期化の実施
G.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# モデルを学習させる関数を作成


def train_model(G, D, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 誤差関数を定義
    criterion = nn.BCEWithLogitsLoss(reduction="mean")

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print("-------------")
        print("Epoch {}/{}".format(epoch, num_epochs))
        print("-------------")
        print("（train）")

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            # issue #186より不要なのでコメントアウト
            # if imges.size()[0] == 1:
            #     continue

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 真の画像を判定
            d_out_real = D(imges)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 誤差を計算
            # d_loss_real = criterion(d_out_real.view(-1), label_real)
            # d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            # d_loss = d_loss_real + d_loss_fake
            label_real = label_real.type_as(d_out_real.view(-1))
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            label_fake = label_fake.type_as(d_out_fake.view(-1))
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print("-------------")
        print(
            "epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}".format(
                epoch, epoch_d_loss / batch_size, epoch_g_loss / batch_size
            )
        )
        print("timer:  {:.4f} sec.".format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    return G, D

# %%
# 学習・検証を実行する
# 6分ほどかかる
num_epochs = 200
G_update, D_update = train_model(G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/200
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.0891 ||Epoch_G_Loss:0.1272
# timer:  0.7343 sec.
# -------------
# Epoch 1/200
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.0187 ||Epoch_G_Loss:0.4699
# timer:  0.1639 sec.
# -------------
# Epoch 2/200
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.2123 ||Epoch_G_Loss:0.1276
# timer:  0.1631 sec.
# -------------
# Epoch 3/200
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.0102 ||Epoch_G_Loss:0.3469
# timer:  0.1622 sec.
# -------------
# Epoch 4/200
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.3248 ||Epoch_G_Loss:0.4500
# timer:  0.1632 sec.
# -------------
# Epoch 5/200
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.0198 ||Epoch_G_Loss:0.2405
# timer:  0.1620 sec.
# -------------
# Epoch 6/200
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.0074 ||Epoch_G_Loss:0.3507
# timer:  0.1643 sec.
# -------------
# Epoch 7/200
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.0033 ||Epoch_G_Loss:0.4570
# timer:  0.1650 sec.
# -------------
# Epoch 8/200
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.2668 ||Epoch_G_Loss:0.3330
# timer:  0.1644 sec.
# -------------
# Epoch 9/200
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.0321 ||Epoch_G_Loss:0.2665
# timer:  0.1644 sec.
# -------------
# Epoch 10/200
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.0086 ||Epoch_G_Loss:0.4009
# timer:  0.1632 sec.
# -------------
# Epoch 11/200
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.4170
# timer:  0.1624 sec.
# -------------
# Epoch 12/200
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.2361 ||Epoch_G_Loss:0.3107
# timer:  0.1649 sec.
# -------------
# Epoch 13/200
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.0198 ||Epoch_G_Loss:0.3515
# timer:  0.1719 sec.
# -------------
# Epoch 14/200
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.1124 ||Epoch_G_Loss:0.2081
# timer:  0.1643 sec.
# -------------
# Epoch 15/200
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0817 ||Epoch_G_Loss:0.2871
# timer:  0.1628 sec.
# -------------
# Epoch 16/200
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0252 ||Epoch_G_Loss:0.3188
# timer:  0.1639 sec.
# -------------
# Epoch 17/200
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0910 ||Epoch_G_Loss:0.3411
# timer:  0.1621 sec.
# -------------
# Epoch 18/200
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.1532 ||Epoch_G_Loss:0.2897
# timer:  0.1641 sec.
# -------------
# Epoch 19/200
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0393 ||Epoch_G_Loss:0.2180
# timer:  0.1652 sec.
# -------------
# Epoch 20/200
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.1060 ||Epoch_G_Loss:0.2733
# timer:  0.1644 sec.
# -------------
# Epoch 21/200
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.0577 ||Epoch_G_Loss:0.2604
# timer:  0.1628 sec.
# -------------
# Epoch 22/200
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0720 ||Epoch_G_Loss:0.2391
# timer:  0.1631 sec.
# -------------
# Epoch 23/200
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.1143 ||Epoch_G_Loss:0.2707
# timer:  0.1620 sec.
# -------------
# Epoch 24/200
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.1057 ||Epoch_G_Loss:0.2202
# timer:  0.1637 sec.
# -------------
# Epoch 25/200
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.0986 ||Epoch_G_Loss:0.2042
# timer:  0.1633 sec.
# -------------
# Epoch 26/200
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.1372 ||Epoch_G_Loss:0.2275
# timer:  0.1635 sec.
# -------------
# Epoch 27/200
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.0742 ||Epoch_G_Loss:0.2249
# timer:  0.1628 sec.
# -------------
# Epoch 28/200
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.0916 ||Epoch_G_Loss:0.1938
# timer:  0.1629 sec.
# -------------
# Epoch 29/200
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.1017 ||Epoch_G_Loss:0.2553
# timer:  0.1625 sec.
# -------------
# Epoch 30/200
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.1169 ||Epoch_G_Loss:0.1498
# timer:  0.1634 sec.
# -------------
# Epoch 31/200
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.0796 ||Epoch_G_Loss:0.2467
# timer:  0.1642 sec.
# -------------
# Epoch 32/200
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.1104 ||Epoch_G_Loss:0.2253
# timer:  0.1657 sec.
# -------------
# Epoch 33/200
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.0965 ||Epoch_G_Loss:0.2079
# timer:  0.1621 sec.
# -------------
# Epoch 34/200
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.1320 ||Epoch_G_Loss:0.1202
# timer:  0.1633 sec.
# -------------
# Epoch 35/200
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.1029 ||Epoch_G_Loss:0.1958
# timer:  0.1629 sec.
# -------------
# Epoch 36/200
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.1344 ||Epoch_G_Loss:0.1741
# timer:  0.1627 sec.
# -------------
# Epoch 37/200
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.0938 ||Epoch_G_Loss:0.1852
# timer:  0.1645 sec.
# -------------
# Epoch 38/200
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.1046 ||Epoch_G_Loss:0.1864
# timer:  0.1638 sec.
# -------------
# Epoch 39/200
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.0982 ||Epoch_G_Loss:0.1704
# timer:  0.1624 sec.
# -------------
# Epoch 40/200
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.1124 ||Epoch_G_Loss:0.1946
# timer:  0.1634 sec.
# -------------
# Epoch 41/200
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.0908 ||Epoch_G_Loss:0.1967
# timer:  0.1621 sec.
# -------------
# Epoch 42/200
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.1415 ||Epoch_G_Loss:0.1035
# timer:  0.1633 sec.
# -------------
# Epoch 43/200
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.1026 ||Epoch_G_Loss:0.1596
# timer:  0.1639 sec.
# -------------
# Epoch 44/200
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.1155 ||Epoch_G_Loss:0.1658
# timer:  0.1654 sec.
# -------------
# Epoch 45/200
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.1137 ||Epoch_G_Loss:0.1512
# timer:  0.1627 sec.
# -------------
# Epoch 46/200
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.1416 ||Epoch_G_Loss:0.1438
# timer:  0.1634 sec.
# -------------
# Epoch 47/200
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.1128 ||Epoch_G_Loss:0.1436
# timer:  0.1621 sec.
# -------------
# Epoch 48/200
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.1222 ||Epoch_G_Loss:0.1161
# timer:  0.1633 sec.
# -------------
# Epoch 49/200
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.1120 ||Epoch_G_Loss:0.1419
# timer:  0.1641 sec.
# -------------
# Epoch 50/200
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.1221 ||Epoch_G_Loss:0.1513
# timer:  0.1659 sec.
# -------------
# Epoch 51/200
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.1089 ||Epoch_G_Loss:0.1488
# timer:  0.1641 sec.
# -------------
# Epoch 52/200
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.1039 ||Epoch_G_Loss:0.1536
# timer:  0.1650 sec.
# -------------
# Epoch 53/200
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.1086 ||Epoch_G_Loss:0.1519
# timer:  0.1637 sec.
# -------------
# Epoch 54/200
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.1303 ||Epoch_G_Loss:0.1522
# timer:  0.1648 sec.
# -------------
# Epoch 55/200
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.1077 ||Epoch_G_Loss:0.1431
# timer:  0.1650 sec.
# -------------
# Epoch 56/200
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.1118 ||Epoch_G_Loss:0.1632
# timer:  0.1673 sec.
# -------------
# Epoch 57/200
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.1016 ||Epoch_G_Loss:0.1470
# timer:  0.1654 sec.
# -------------
# Epoch 58/200
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.1086 ||Epoch_G_Loss:0.1919
# timer:  0.1650 sec.
# -------------
# Epoch 59/200
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.0907 ||Epoch_G_Loss:0.1424
# timer:  0.1639 sec.
# -------------
# Epoch 60/200
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.1198 ||Epoch_G_Loss:0.1793
# timer:  0.1652 sec.
# -------------
# Epoch 61/200
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1564
# timer:  0.1648 sec.
# -------------
# Epoch 62/200
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.0964 ||Epoch_G_Loss:0.1722
# timer:  0.1668 sec.
# -------------
# Epoch 63/200
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.0898 ||Epoch_G_Loss:0.1697
# timer:  0.1645 sec.
# -------------
# Epoch 64/200
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.0975 ||Epoch_G_Loss:0.1829
# timer:  0.1657 sec.
# -------------
# Epoch 65/200
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.0913 ||Epoch_G_Loss:0.1826
# timer:  0.1639 sec.
# -------------
# Epoch 66/200
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.0960 ||Epoch_G_Loss:0.1845
# timer:  0.1667 sec.
# -------------
# Epoch 67/200
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.0841 ||Epoch_G_Loss:0.1912
# timer:  0.1656 sec.
# -------------
# Epoch 68/200
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.0943 ||Epoch_G_Loss:0.1902
# timer:  0.1661 sec.
# -------------
# Epoch 69/200
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.0925 ||Epoch_G_Loss:0.1835
# timer:  0.1670 sec.
# -------------
# Epoch 70/200
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0926 ||Epoch_G_Loss:0.2123
# timer:  0.1653 sec.
# -------------
# Epoch 71/200
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.1097 ||Epoch_G_Loss:0.1601
# timer:  0.1640 sec.
# -------------
# Epoch 72/200
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0837 ||Epoch_G_Loss:0.1860
# timer:  0.1648 sec.
# -------------
# Epoch 73/200
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.0854 ||Epoch_G_Loss:0.1761
# timer:  0.1640 sec.
# -------------
# Epoch 74/200
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.0980 ||Epoch_G_Loss:0.2084
# timer:  0.1643 sec.
# -------------
# Epoch 75/200
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0828 ||Epoch_G_Loss:0.1854
# timer:  0.1590 sec.
# -------------
# Epoch 76/200
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.0913 ||Epoch_G_Loss:0.2011
# timer:  0.1598 sec.
# -------------
# Epoch 77/200
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0888 ||Epoch_G_Loss:0.1844
# timer:  0.1597 sec.
# -------------
# Epoch 78/200
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0897 ||Epoch_G_Loss:0.2033
# timer:  0.1603 sec.
# -------------
# Epoch 79/200
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.0800 ||Epoch_G_Loss:0.1753
# timer:  0.1596 sec.
# -------------
# Epoch 80/200
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0881 ||Epoch_G_Loss:0.2151
# timer:  0.1618 sec.
# -------------
# Epoch 81/200
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.1093 ||Epoch_G_Loss:0.1753
# timer:  0.1617 sec.
# -------------
# Epoch 82/200
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0754 ||Epoch_G_Loss:0.2126
# timer:  0.1608 sec.
# -------------
# Epoch 83/200
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.0954 ||Epoch_G_Loss:0.1711
# timer:  0.1595 sec.
# -------------
# Epoch 84/200
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0828 ||Epoch_G_Loss:0.2019
# timer:  0.1603 sec.
# -------------
# Epoch 85/200
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.0847 ||Epoch_G_Loss:0.2174
# timer:  0.1592 sec.
# -------------
# Epoch 86/200
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.0802 ||Epoch_G_Loss:0.2123
# timer:  0.1611 sec.
# -------------
# Epoch 87/200
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0876 ||Epoch_G_Loss:0.2089
# timer:  0.1604 sec.
# -------------
# Epoch 88/200
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.0884 ||Epoch_G_Loss:0.2008
# timer:  0.1599 sec.
# -------------
# Epoch 89/200
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0754 ||Epoch_G_Loss:0.2347
# timer:  0.1592 sec.
# -------------
# Epoch 90/200
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0793 ||Epoch_G_Loss:0.2032
# timer:  0.1605 sec.
# -------------
# Epoch 91/200
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0902 ||Epoch_G_Loss:0.2088
# timer:  0.1595 sec.
# -------------
# Epoch 92/200
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0912 ||Epoch_G_Loss:0.2190
# timer:  0.1612 sec.
# -------------
# Epoch 93/200
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.0728 ||Epoch_G_Loss:0.2333
# timer:  0.1607 sec.
# -------------
# Epoch 94/200
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0969 ||Epoch_G_Loss:0.1625
# timer:  0.1624 sec.
# -------------
# Epoch 95/200
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0875 ||Epoch_G_Loss:0.2146
# timer:  0.1598 sec.
# -------------
# Epoch 96/200
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0646 ||Epoch_G_Loss:0.2054
# timer:  0.1606 sec.
# -------------
# Epoch 97/200
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0877 ||Epoch_G_Loss:0.2263
# timer:  0.1600 sec.
# -------------
# Epoch 98/200
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0784 ||Epoch_G_Loss:0.2102
# timer:  0.1613 sec.
# -------------
# Epoch 99/200
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0631 ||Epoch_G_Loss:0.2473
# timer:  0.1604 sec.
# -------------
# Epoch 100/200
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0919 ||Epoch_G_Loss:0.1770
# timer:  0.1607 sec.
# -------------
# Epoch 101/200
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0796 ||Epoch_G_Loss:0.2318
# timer:  0.1594 sec.
# -------------
# Epoch 102/200
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0905 ||Epoch_G_Loss:0.2174
# timer:  0.1606 sec.
# -------------
# Epoch 103/200
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0664 ||Epoch_G_Loss:0.2354
# timer:  0.1591 sec.
# -------------
# Epoch 104/200
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0774 ||Epoch_G_Loss:0.2418
# timer:  0.1611 sec.
# -------------
# Epoch 105/200
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0861 ||Epoch_G_Loss:0.2140
# timer:  0.1611 sec.
# -------------
# Epoch 106/200
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0751 ||Epoch_G_Loss:0.2442
# timer:  0.1614 sec.
# -------------
# Epoch 107/200
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0771 ||Epoch_G_Loss:0.2196
# timer:  0.1617 sec.
# -------------
# Epoch 108/200
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0732 ||Epoch_G_Loss:0.2462
# timer:  0.1614 sec.
# -------------
# Epoch 109/200
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0828 ||Epoch_G_Loss:0.2253
# timer:  0.1606 sec.
# -------------
# Epoch 110/200
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0734 ||Epoch_G_Loss:0.2682
# timer:  0.1621 sec.
# -------------
# Epoch 111/200
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0796 ||Epoch_G_Loss:0.1882
# timer:  0.1615 sec.
# -------------
# Epoch 112/200
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0825 ||Epoch_G_Loss:0.2618
# timer:  0.1620 sec.
# -------------
# Epoch 113/200
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0772 ||Epoch_G_Loss:0.2219
# timer:  0.1608 sec.
# -------------
# Epoch 114/200
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0714 ||Epoch_G_Loss:0.2586
# timer:  0.1617 sec.
# -------------
# Epoch 115/200
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0695 ||Epoch_G_Loss:0.2359
# timer:  0.1604 sec.
# -------------
# Epoch 116/200
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0821 ||Epoch_G_Loss:0.2439
# timer:  0.1609 sec.
# -------------
# Epoch 117/200
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0731 ||Epoch_G_Loss:0.2352
# timer:  0.1624 sec.
# -------------
# Epoch 118/200
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0635 ||Epoch_G_Loss:0.2926
# timer:  0.1624 sec.
# -------------
# Epoch 119/200
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0662 ||Epoch_G_Loss:0.2046
# timer:  0.1636 sec.
# -------------
# Epoch 120/200
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0835 ||Epoch_G_Loss:0.2689
# timer:  0.1614 sec.
# -------------
# Epoch 121/200
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0653 ||Epoch_G_Loss:0.2474
# timer:  0.1637 sec.
# -------------
# Epoch 122/200
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0706 ||Epoch_G_Loss:0.2540
# timer:  0.1621 sec.
# -------------
# Epoch 123/200
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0682 ||Epoch_G_Loss:0.2869
# timer:  0.1621 sec.
# -------------
# Epoch 124/200
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0618 ||Epoch_G_Loss:0.2562
# timer:  0.1621 sec.
# -------------
# Epoch 125/200
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.0658 ||Epoch_G_Loss:0.2610
# timer:  0.1636 sec.
# -------------
# Epoch 126/200
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0493 ||Epoch_G_Loss:0.2943
# timer:  0.1625 sec.
# -------------
# Epoch 127/200
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0867 ||Epoch_G_Loss:0.2773
# timer:  0.1600 sec.
# -------------
# Epoch 128/200
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0742 ||Epoch_G_Loss:0.2825
# timer:  0.1609 sec.
# -------------
# Epoch 129/200
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0591 ||Epoch_G_Loss:0.2263
# timer:  0.1630 sec.
# -------------
# Epoch 130/200
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0812 ||Epoch_G_Loss:0.2678
# timer:  0.1633 sec.
# -------------
# Epoch 131/200
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0510 ||Epoch_G_Loss:0.2766
# timer:  0.1620 sec.
# -------------
# Epoch 132/200
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0664 ||Epoch_G_Loss:0.2913
# timer:  0.1622 sec.
# -------------
# Epoch 133/200
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0607 ||Epoch_G_Loss:0.2653
# timer:  0.1611 sec.
# -------------
# Epoch 134/200
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0733 ||Epoch_G_Loss:0.2875
# timer:  0.1603 sec.
# -------------
# Epoch 135/200
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0608 ||Epoch_G_Loss:0.2780
# timer:  0.1600 sec.
# -------------
# Epoch 136/200
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0577 ||Epoch_G_Loss:0.3305
# timer:  0.1628 sec.
# -------------
# Epoch 137/200
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0583 ||Epoch_G_Loss:0.2922
# timer:  0.1610 sec.
# -------------
# Epoch 138/200
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0716 ||Epoch_G_Loss:0.2815
# timer:  0.1607 sec.
# -------------
# Epoch 139/200
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0551 ||Epoch_G_Loss:0.3226
# timer:  0.1599 sec.
# -------------
# Epoch 140/200
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0647 ||Epoch_G_Loss:0.2866
# timer:  0.1607 sec.
# -------------
# Epoch 141/200
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0361 ||Epoch_G_Loss:0.3638
# timer:  0.1605 sec.
# -------------
# Epoch 142/200
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0924 ||Epoch_G_Loss:0.2379
# timer:  0.1645 sec.
# -------------
# Epoch 143/200
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0596 ||Epoch_G_Loss:0.3077
# timer:  0.1633 sec.
# -------------
# Epoch 144/200
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0572 ||Epoch_G_Loss:0.3128
# timer:  0.1658 sec.
# -------------
# Epoch 145/200
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0537 ||Epoch_G_Loss:0.3084
# timer:  0.1634 sec.
# -------------
# Epoch 146/200
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0567 ||Epoch_G_Loss:0.3227
# timer:  0.1642 sec.
# -------------
# Epoch 147/200
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0735 ||Epoch_G_Loss:0.3585
# timer:  0.1631 sec.
# -------------
# Epoch 148/200
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0475 ||Epoch_G_Loss:0.3133
# timer:  0.1648 sec.
# -------------
# Epoch 149/200
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0498 ||Epoch_G_Loss:0.3284
# timer:  0.1635 sec.
# -------------
# Epoch 150/200
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0774 ||Epoch_G_Loss:0.3131
# timer:  0.1645 sec.
# -------------
# Epoch 151/200
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0594 ||Epoch_G_Loss:0.3464
# timer:  0.1626 sec.
# -------------
# Epoch 152/200
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0575 ||Epoch_G_Loss:0.3081
# timer:  0.1638 sec.
# -------------
# Epoch 153/200
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0546 ||Epoch_G_Loss:0.3113
# timer:  0.1623 sec.
# -------------
# Epoch 154/200
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0571 ||Epoch_G_Loss:0.3178
# timer:  0.1641 sec.
# -------------
# Epoch 155/200
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0449 ||Epoch_G_Loss:0.3436
# timer:  0.1636 sec.
# -------------
# Epoch 156/200
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0441 ||Epoch_G_Loss:0.3517
# timer:  0.1648 sec.
# -------------
# Epoch 157/200
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0738 ||Epoch_G_Loss:0.3152
# timer:  0.1647 sec.
# -------------
# Epoch 158/200
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0503 ||Epoch_G_Loss:0.3219
# timer:  0.1641 sec.
# -------------
# Epoch 159/200
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0426 ||Epoch_G_Loss:0.3669
# timer:  0.1632 sec.
# -------------
# Epoch 160/200
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0622 ||Epoch_G_Loss:0.3204
# timer:  0.1652 sec.
# -------------
# Epoch 161/200
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0428 ||Epoch_G_Loss:0.3352
# timer:  0.1642 sec.
# -------------
# Epoch 162/200
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0511 ||Epoch_G_Loss:0.3357
# timer:  0.1637 sec.
# -------------
# Epoch 163/200
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0508 ||Epoch_G_Loss:0.3872
# timer:  0.1637 sec.
# -------------
# Epoch 164/200
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.0481 ||Epoch_G_Loss:0.3179
# timer:  0.1641 sec.
# -------------
# Epoch 165/200
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.0662 ||Epoch_G_Loss:0.3470
# timer:  0.1628 sec.
# -------------
# Epoch 166/200
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0352 ||Epoch_G_Loss:0.3617
# timer:  0.1670 sec.
# -------------
# Epoch 167/200
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.0516 ||Epoch_G_Loss:0.3866
# timer:  0.1641 sec.
# -------------
# Epoch 168/200
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.0572 ||Epoch_G_Loss:0.3571
# timer:  0.1641 sec.
# -------------
# Epoch 169/200
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0474 ||Epoch_G_Loss:0.3326
# timer:  0.1676 sec.
# -------------
# Epoch 170/200
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.0441 ||Epoch_G_Loss:0.3642
# timer:  0.1649 sec.
# -------------
# Epoch 171/200
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0536 ||Epoch_G_Loss:0.3324
# timer:  0.1630 sec.
# -------------
# Epoch 172/200
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.0418 ||Epoch_G_Loss:0.3949
# timer:  0.1644 sec.
# -------------
# Epoch 173/200
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.0603 ||Epoch_G_Loss:0.3013
# timer:  0.1643 sec.
# -------------
# Epoch 174/200
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0327 ||Epoch_G_Loss:0.3604
# timer:  0.1643 sec.
# -------------
# Epoch 175/200
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0573 ||Epoch_G_Loss:0.3637
# timer:  0.1639 sec.
# -------------
# Epoch 176/200
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0292 ||Epoch_G_Loss:0.3683
# timer:  0.1647 sec.
# -------------
# Epoch 177/200
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0717 ||Epoch_G_Loss:0.3841
# timer:  0.1640 sec.
# -------------
# Epoch 178/200
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0340 ||Epoch_G_Loss:0.3773
# timer:  0.1658 sec.
# -------------
# Epoch 179/200
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0509 ||Epoch_G_Loss:0.3992
# timer:  0.1652 sec.
# -------------
# Epoch 180/200
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0414 ||Epoch_G_Loss:0.3659
# timer:  0.1655 sec.
# -------------
# Epoch 181/200
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0550 ||Epoch_G_Loss:0.4004
# timer:  0.1660 sec.
# -------------
# Epoch 182/200
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0382 ||Epoch_G_Loss:0.3750
# timer:  0.1658 sec.
# -------------
# Epoch 183/200
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0341 ||Epoch_G_Loss:0.4018
# timer:  0.1643 sec.
# -------------
# Epoch 184/200
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.0587 ||Epoch_G_Loss:0.3777
# timer:  0.1649 sec.
# -------------
# Epoch 185/200
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.0468 ||Epoch_G_Loss:0.3155
# timer:  0.1652 sec.
# -------------
# Epoch 186/200
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0382 ||Epoch_G_Loss:0.4173
# timer:  0.1660 sec.
# -------------
# Epoch 187/200
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.0375 ||Epoch_G_Loss:0.3772
# timer:  0.1639 sec.
# -------------
# Epoch 188/200
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0483 ||Epoch_G_Loss:0.4218
# timer:  0.1647 sec.
# -------------
# Epoch 189/200
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0290 ||Epoch_G_Loss:0.4189
# timer:  0.1642 sec.
# -------------
# Epoch 190/200
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0287 ||Epoch_G_Loss:0.4298
# timer:  0.1652 sec.
# -------------
# Epoch 191/200
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0546 ||Epoch_G_Loss:0.4037
# timer:  0.1652 sec.
# -------------
# Epoch 192/200
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0297 ||Epoch_G_Loss:0.4633
# timer:  0.1634 sec.
# -------------
# Epoch 193/200
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0663 ||Epoch_G_Loss:0.3131
# timer:  0.1602 sec.
# -------------
# Epoch 194/200
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.0237 ||Epoch_G_Loss:0.3948
# timer:  0.1610 sec.
# -------------
# Epoch 195/200
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.0503 ||Epoch_G_Loss:0.4428
# timer:  0.1597 sec.
# -------------
# Epoch 196/200
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.0227 ||Epoch_G_Loss:0.4621
# timer:  0.1602 sec.
# -------------
# Epoch 197/200
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.0576 ||Epoch_G_Loss:0.3779
# timer:  0.1610 sec.
# -------------
# Epoch 198/200
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.0354 ||Epoch_G_Loss:0.4487
# timer:  0.1609 sec.
# -------------
# Epoch 199/200
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.0279 ||Epoch_G_Loss:0.4389
# timer:  0.1595 sec.

# %%
# 生成画像と訓練データを可視化する
# 本セルは良い感じの画像が生成されるまで、何度も実行し直しています。

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 画像生成
G_update.eval()
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i + 1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), "gray")

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5 + i + 1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), "gray")

# %% [markdown]
# 以上
